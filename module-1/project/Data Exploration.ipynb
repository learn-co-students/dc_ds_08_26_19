# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('data/bom.movie_gross.csv')
# Out:
#                                                   title      studio  \
# 0                                           Toy Story 3          BV
# 1                            Alice in Wonderland (2010)          BV
# 2           Harry Potter and the Deathly Hallows Part 1          WB
# 3                                             Inception          WB
# 4                                   Shrek Forever After        P/DW
# 5                            The Twilight Saga: Eclipse        Sum.
# 6                                            Iron Man 2        Par.
# 7                                               Tangled          BV
# 8                                         Despicable Me        Uni.
# 9                              How to Train Your Dragon        P/DW
# 10                           Clash of the Titans (2010)          WB
# 11    The Chronicles of Narnia: The Voyage of the Da...         Fox
# 12                                    The King's Speech       Wein.
# ...

# %%
bom_df = pd.read_csv('data/bom.movie_gross.csv')

# %%
bom_df
# Out:
#                                                   title      studio  \
# 0                                           Toy Story 3          BV
# 1                            Alice in Wonderland (2010)          BV
# 2           Harry Potter and the Deathly Hallows Part 1          WB
# 3                                             Inception          WB
# 4                                   Shrek Forever After        P/DW
# 5                            The Twilight Saga: Eclipse        Sum.
# 6                                            Iron Man 2        Par.
# 7                                               Tangled          BV
# 8                                         Despicable Me        Uni.
# 9                              How to Train Your Dragon        P/DW
# 10                           Clash of the Titans (2010)          WB
# 11    The Chronicles of Narnia: The Voyage of the Da...         Fox
# 12                                    The King's Speech       Wein.
# ...

# %%
type(bom_df.iloc[3384]['foreign_gross'])
# Out:
# float

# %%
bom_df = bom_df.fillna(0)

# %%
bom_df.describe()
# Out:
#        domestic_gross         year   total_gross
# count    3.387000e+03  3387.000000  3.387000e+03
# mean     2.850821e+07  2013.958075  2.850821e+07
# std      6.675575e+07     2.478141  6.675575e+07
# min      0.000000e+00  2010.000000  0.000000e+00
# 25%      1.115000e+05  2012.000000  1.115010e+05
# 50%      1.300000e+06  2014.000000  1.300001e+06
# 75%      2.750000e+07  2016.000000  2.750000e+07
# max      9.367000e+08  2018.000000  9.367000e+08

# %%
bom_df
# Out:
#                                                   title      studio  \
# 0                                           Toy Story 3          BV
# 1                            Alice in Wonderland (2010)          BV
# 2           Harry Potter and the Deathly Hallows Part 1          WB
# 3                                             Inception          WB
# 4                                   Shrek Forever After        P/DW
# 5                            The Twilight Saga: Eclipse        Sum.
# 6                                            Iron Man 2        Par.
# 7                                               Tangled          BV
# 8                                         Despicable Me        Uni.
# 9                              How to Train Your Dragon        P/DW
# 10                           Clash of the Titans (2010)          WB
# 11    The Chronicles of Narnia: The Voyage of the Da...         Fox
# 12                                    The King's Speech       Wein.
# ...

# %%
bom_df['total_gross'] = bom_df['domestic_gross'] + bom_df['foreign_gross']

# %%
bom_df.describe()
# Out:
#        domestic_gross  foreign_gross         year   total_gross
# count    3.387000e+03   3.387000e+03  3387.000000  3.387000e+03
# mean     2.850821e+07   4.502979e+07  2013.958075  7.353800e+07
# std      6.675575e+07   1.126843e+08     2.478141  1.705091e+08
# min      0.000000e+00   0.000000e+00  2010.000000  1.000000e+02
# 25%      1.115000e+05   0.000000e+00  2012.000000  2.740000e+05
# 50%      1.300000e+06   1.500000e+06  2014.000000  5.475000e+06
# 75%      2.750000e+07   2.915000e+07  2016.000000  6.135000e+07
# max      9.367000e+08   9.605000e+08  2018.000000  1.518900e+09

# %%
bom_df
# Out:
#                                                   title      studio  \
# 0                                           Toy Story 3          BV
# 1                            Alice in Wonderland (2010)          BV
# 2           Harry Potter and the Deathly Hallows Part 1          WB
# 3                                             Inception          WB
# 4                                   Shrek Forever After        P/DW
# 5                            The Twilight Saga: Eclipse        Sum.
# 6                                            Iron Man 2        Par.
# 7                                               Tangled          BV
# 8                                         Despicable Me        Uni.
# 9                              How to Train Your Dragon        P/DW
# 10                           Clash of the Titans (2010)          WB
# 11    The Chronicles of Narnia: The Voyage of the Da...         Fox
# 12                                    The King's Speech       Wein.
# ...

# %%
bom_df['foreign_gross'] = pd.to_numeric(bom_df['foreign_gross'])

# %%
bom_df['foreign_gross'] = bom_df['foreign_gross'].str.replace(',', '')

# %%
bom_df['total_gross']
# Out:
# 0       1.067000e+09
# 1       1.025500e+09
# 2       9.603000e+08
# 3       8.283000e+08
# 4       7.526000e+08
# 5       6.985000e+08
# 6       6.239000e+08
# 7       5.918000e+08
# 8       5.431000e+08
# 9       4.949000e+08
# 10      4.932000e+08
# 11      4.157000e+08
# 12      4.109000e+08
# 13      4.001000e+08
# 14      3.591000e+08
# 15      3.364000e+08
# 16      3.294000e+08
# 17      3.219000e+08
# 18      3.217000e+08
# 19      3.197000e+08
# 20      3.106000e+08
# 21      3.002000e+08
# 22      2.948000e+08
# 23      2.935000e+08
# 24      2.883000e+08
# 25      2.783000e+08
# 26      2.745000e+08
# 27      2.714000e+08
# 28      2.619000e+08
# 29      2.522000e+08
#             ...
# 3357    5.090000e+04
# 3358    4.630000e+04
# 3359    4.430000e+04
# 3360    4.420000e+04
# 3361    4.190000e+04
# 3362    3.770000e+04
# 3363    3.710000e+04
# 3364    3.640000e+04
# 3365    2.830000e+04
# 3366    2.620000e+04
# 3367    2.430000e+04
# 3368    2.210000e+04
# ...

# %%
type(bom_df)
# Out:
# pandas.core.frame.DataFrame

# %%
bom_df = bom_df.sort_values('total_gross', ascending=False)

# %%
bom_df['domestic_percentage'] = bom_df['domestic_gross'] / bom_df['total_gross']

# %%
bom_df
# Out:
#                                             title      studio  domestic_gross  \
# 727                         Marvel's The Avengers          BV     623400000.0
# 1875                      Avengers: Age of Ultron          BV     459000000.0
# 3080                                Black Panther          BV     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2          WB     381000000.0
# 2758                     Star Wars: The Last Jedi          BV     620200000.0
# 3081               Jurassic World: Fallen Kingdom        Uni.     417700000.0
# 1127                                       Frozen          BV     400700000.0
# 2759                  Beauty and the Beast (2017)          BV     504000000.0
# 3082                                Incredibles 2          BV     608600000.0
# 1128                                   Iron Man 3          BV     409000000.0
# 1876                                      Minions        Uni.     336000000.0
# ...

# %%
pd.read_csv('data/imdb.name.basics.csv')
# Out:
#            nconst           primary_name  birth_year  death_year  \
# 0       nm0061671      Mary Ellen Bauder         NaN         NaN
# 1       nm0061865           Joseph Bauer         NaN         NaN
# 2       nm0062070             Bruce Baum         NaN         NaN
# 3       nm0062195           Axel Baumann         NaN         NaN
# 4       nm0062798            Pete Baxter         NaN         NaN
# 5       nm0062879         Ruel S. Bayani         NaN         NaN
# 6       nm0063198                  Bayou         NaN         NaN
# 7       nm0063432          Stevie Be-Zet         NaN         NaN
# 8       nm0063618              Jeff Beal      1963.0         NaN
# 9       nm0063750        Lindsay Beamish         NaN         NaN
# 10      nm0064023          Bryan Beasley         NaN         NaN
# 11      nm0064350     Martine Beauchemin         NaN         NaN
# 12      nm0065847  Michael Frost Beckner      1963.0         NaN
# ...

# %%
pd.read_csv('data/imdb.title.akas.csv')
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# 5       tt0369610        15                           Jurassic World     GR
# 6       tt0369610        16                           Jurassic World     IT
# 7       tt0369610        17                            Jurski svijet     HR
# 8       tt0369610        18                             Olam ha'Yura     IL
# 9       tt0369610        19           Jurassic World: Mundo Jurásico     MX
# 10      tt0369610         1          Jurassic World: Sauruste maailm     EE
# ...

# %%
pd.read_csv('data/imdb.title.basics.csv')
# Out:
#            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0069204                                    Sabse Bada Sukh
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# 6       tt0112502                                            Bigfoot
# 7       tt0137204                                    Joe Finds Grace
# 8       tt0139613                                         O Silêncio
# 9       tt0144449                              Nema aviona za Zagreb
# 10      tt0146592                                        Pál Adrienn
# 11      tt0154039                               So Much for Justice!
# 12      tt0159369                 Cooper and Hemingway: The True Gen
# ...

# %%
pd.read_csv('data/imdb.title.crew.csv')
# Out:
#             tconst                      directors  \
# 0        tt0285252                      nm0899854
# 1        tt0438973                            NaN
# 2        tt0462036                      nm1940585
# 3        tt0835418                      nm0151540
# 4        tt0878654  nm0089502,nm2291498,nm2292011
# 5        tt0879859                      nm2416460
# 6        tt0996958                      nm2286991
# 7        tt0999913                      nm0527109
# 8       tt10003792                     nm10539228
# 9       tt10005130                     nm10540239
# 10      tt10005378                      nm9232888
# 11      tt10011102                      nm4853354
# 12       tt1002965                      nm0860520
# 13      tt10036406                     nm10553970
# 14      tt10039152                      nm6021959
# 15      tt10042456                      nm6051389
# 16      tt10055770                      nm8351963
# 17      tt10056334                     nm10563021
# ...

# %%
pd.read_csv('data/imdb.title.principals.csv')
# Out:
#             tconst  ordering      nconst         category       job  \
# 0        tt0111414         1   nm0246005            actor       NaN
# 1        tt0111414         2   nm0398271         director       NaN
# 2        tt0111414         3   nm3739909         producer  producer
# 3        tt0323808        10   nm0059247           editor       NaN
# 4        tt0323808         1   nm3579312          actress       NaN
# 5        tt0323808         2   nm2694680            actor       NaN
# 6        tt0323808         3   nm0574615            actor       NaN
# 7        tt0323808         4   nm0502652          actress       NaN
# 8        tt0323808         5   nm0362736         director       NaN
# 9        tt0323808         6   nm0811056         producer  producer
# 10       tt0323808         7   nm0914939         producer  producer
# 11       tt0323808         8   nm0779346         composer       NaN
# 12       tt0323808         9   nm0676104  cinematographer       NaN
# ...

# %%
pd.read_csv('data/imdb.title.ratings.csv')
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# 5       tt1069246            6.2       326
# 6       tt1094666            7.0      1613
# 7       tt1130982            6.4       571
# 8       tt1156528            7.2       265
# 9       tt1161457            4.2       148
# 10      tt1171222            5.1      8296
# 11      tt1174693            5.8      2381
# 12      tt1181840            7.0      5494
# 13      tt1193623            8.0         5
# 14      tt1199588            5.5        74
# 15      tt1204784            5.8         6
# 16      tt1210166            7.6    326657
# 17      tt1212419            6.5     87288
# 18      tt1220911            5.0       941
# 19      tt1229238            7.4    428142
# 20      tt1232829            7.2    477771
# ...

# %%
import re
tsv = open('data/rt.movie_info.tsv', 'r')
fileContent =  tsv.read()
fileContent = re.sub("\t", ",", fileContent) # convert from tab to comma
csv_file = open("new.rt.movie_info.csv", "w")
csv_file.write(fileContent)
csv_file.close()

# %%
'new.rt.movie_info.csv'
# Out:
# 'new.rt.movie_info.csv'

# %%
rt_df = pd.read_csv('data/rt.movie_info.tsv', sep='\t')

# %%
rt_df.columns
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')

# %%
rt_df
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# 5        8  The year is 1942. As the Allies unite overseas...     PG
# 6       10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7       13  Stewart Kane, an Irishman living in the Austra...      R
# 8       14  "Love Ranch" is a bittersweet love story that ...      R
# 9       15  When a diamond expedition in the Congo is lost...  PG-13
# 10      17                                                NaN    NaN
# 11      18  In 1979, Bill Viola and Frank Caliguri dreamed...     NR
# 12      19  While Microsoft may be the biggest software co...     NR
# ...

# %%
rt_reviews_df = pd.read_csv('data/rt.reviews.tsv', sep='\t', encoding='latin1')

# %%
rt_reviews_df
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# 5         3  ... Cronenberg's Cosmopolis expresses somethin...    NaN   fresh
# 6         3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7         3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 8         3  Cronenberg's cold, exacting precision and emot...    NaN   fresh
# 9         3  Over and above its topical urgency or the bit ...    NaN   fresh
# 10        3  Cosmopolis" is a hypnotic examination of our m...    NaN   fresh
# ...

# %%
tmdb_df = pd.read_csv('data/tmdb.movies.csv')

# %%
tmdb_df
# Out:
#        Unnamed: 0                 genre_ids      id original_language  \
# 0               0           [12, 14, 10751]   12444                en
# 1               1       [14, 12, 16, 10751]   10191                en
# 2               2             [12, 28, 878]   10138                en
# 3               3           [16, 35, 10751]     862                en
# 4               4             [28, 878, 12]   27205                en
# 5               5           [12, 14, 10751]   32657                en
# 6               6         [28, 12, 14, 878]   19995                en
# 7               7           [16, 10751, 35]   10193                en
# 8               8           [16, 10751, 35]   20352                en
# 9               9  [16, 28, 35, 10751, 878]   38055                en
# 10             10           [16, 35, 10751]     863                en
# 11             11           [10751, 14, 12]   12155                en
# ...

# %%
tmdb_df.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
tn_df = pd.read_csv('data/tn.movie_budgets.csv')

# %%
tn_df
# Out:
#       id  release_date                                             movie  \
# 0      1  Dec 18, 2009                                            Avatar
# 1      2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                      Dark Phoenix
# 3      4   May 1, 2015                           Avengers: Age of Ultron
# 4      5  Dec 15, 2017                 Star Wars Ep. VIII: The Last Jedi
# 5      6  Dec 18, 2015              Star Wars Ep. VII: The Force Awakens
# 6      7  Apr 27, 2018                            Avengers: Infinity War
# 7      8  May 24, 2007        Pirates of the Caribbean: At Worldâs End
# 8      9  Nov 17, 2017                                    Justice League
# 9     10   Nov 6, 2015                                           Spectre
# 10    11  Jul 20, 2012                             The Dark Knight Rises
# 11    12  May 25, 2018                           Solo: A Star Wars Story
# ...

# %%
tn_df.sort_values('production_budget')
# Out:
#        id  release_date                                              movie  \
# 5283   84   Jul 1, 2011                                   The Perfect Host
# 5301    2  Dec 31, 2006                                   Loving Annabelle
# 5302    3  Dec 11, 2015                                      American Hero
# 5303    4   Dec 1, 2009                                         Frat Party
# 5304    5  Sep 15, 2006                                     Jimmy and Judy
# 5305    6  Oct 24, 2003                                   The Party's Over
# 5306    7  Jul 17, 2009                                    The Poker House
# 5307    8  Sep 23, 2005                                              Proud
# 5308    9  Dec 31, 2008                                 Steppin: The Movie
# 5309   10  Jan 29, 2010                        Zombies of Mass Destruction
# 5310   11  Mar 20, 2012                        Snow White: A Deadly Summer
# ...

# %%
tn_df['production_budget'] = tn_df['production_budget'].str.replace('$', '')
tn_df['domestic_gross'] = tn_df['domestic_gross'].str.replace('$', '')
tn_df['worldwide_gross'] = tn_df['worldwide_gross'].str.replace('$', '')
tn_df['production_budget'] = tn_df['production_budget'].str.replace(',', '')
tn_df['domestic_gross'] = tn_df['domestic_gross'].str.replace(',', '')
tn_df['worldwide_gross'] = tn_df['worldwide_gross'].str.replace(',', '')

# %%
tn_df
# Out:
#       id  release_date                                             movie  \
# 0      1  Dec 18, 2009                                            Avatar
# 1      2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                      Dark Phoenix
# 3      4   May 1, 2015                           Avengers: Age of Ultron
# 4      5  Dec 15, 2017                 Star Wars Ep. VIII: The Last Jedi
# 5      6  Dec 18, 2015              Star Wars Ep. VII: The Force Awakens
# 6      7  Apr 27, 2018                            Avengers: Infinity War
# 7      8  May 24, 2007        Pirates of the Caribbean: At Worldâs End
# 8      9  Nov 17, 2017                                    Justice League
# 9     10   Nov 6, 2015                                           Spectre
# 10    11  Jul 20, 2012                             The Dark Knight Rises
# 11    12  May 25, 2018                           Solo: A Star Wars Story
# ...

# %%
tn_df['worldwide_gross'] = pd.to_numeric(tn_df['worldwide_gross'])
tn_df['domestic_gross'] = pd.to_numeric(tn_df['domestic_gross'])
tn_df['production_budget'] = pd.to_numeric(tn_df['production_budget'])

# %%
tn_df.sort_values('production_budget')
# Out:
#       id  release_date                                             movie  \
# 5781  82   Aug 5, 2005                                 My Date With Drew
# 5780  81  Sep 29, 2015                              A Plague So Pleasant
# 5779  80  Jul 13, 2005                     Return to the Land of Wonders
# 5778  79   Apr 2, 1999                                         Following
# 5776  77  Dec 31, 2004                                   The Mongol King
# 5775  76  May 26, 2006                                            Cavite
# 5774  75   Oct 8, 2004                                            Primer
# 5773  74  Feb 26, 1993                                       El Mariachi
# 5777  78  Dec 31, 2018                                            Red 11
# 5772  73  Jan 13, 2012                                         Newlyweds
# 5765  66   Mar 9, 2001                                           Dayereh
# 5768  69  May 28, 2004                                    On the Downlow
# ...

# %%
new_tn_df = tn_df[tn_df['production_budget'] >= 100000000]

# %%
new_new_tn_df = new_tn_df.sort_values('production_budget', ascending = True)

# %%
new_new_tn_df
# Out:
#       id  release_date                                             movie  \
# 405    6  Jan 20, 2012                           Jin lÃ­ng shÃ­ san chai
# 380   81  Aug 17, 2012                                 The Expendables 2
# 379   80  Dec 15, 2000                          The Emperor's New Groove
# 378   79  Jun 21, 1996                       The Hunchback of Notre Dame
# 377   78  Jun 21, 1996                                            Eraser
# 376   77  May 24, 2013                                              Epic
# 375   76  Dec 25, 2013                           The Wolf of Wall Street
# 374   75  Dec 17, 2004   Lemony Snicket's A Series of Unfortunate Events
# 373   74   Aug 6, 2010                                    The Other Guys
# 381   82  Oct 16, 2009                         Where the Wild Things Are
# 372   73  Sep 18, 2009                 Cloudy with a Chance of Meatballs
# 370   71  Jul 15, 1994                                         True Lies
# ...

# %%
new_new_tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406 entries, 405 to 0
# Data columns (total 6 columns):
# id                   406 non-null int64
# release_date         406 non-null object
# movie                406 non-null object
# production_budget    406 non-null int64
# domestic_gross       406 non-null int64
# worldwide_gross      406 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 22.2+ KB

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null int64
# domestic_gross       5782 non-null int64
# worldwide_gross      5782 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 271.1+ KB

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
ax = sns.scatterplot(x="production_budget", y="worldwide_gross", data=new_new_tn_df)

# %%
import matplotlib as mpl
