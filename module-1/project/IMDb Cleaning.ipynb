# %%
import pandas as pd
import numpy as np

# %%
name_df = pd.read_csv('data/imdb.name.basics.csv')
title_akas_df = pd.read_csv('data/imdb.title.akas.csv')
title_basics_df = pd.read_csv('data/imdb.title.basics.csv')
title_crew_df = pd.read_csv('data/imdb.title.crew.csv')
title_principals_df = pd.read_csv('data/imdb.title.principals.csv')
title_rating_df = pd.read_csv('data/imdb.title.ratings.csv')

# %%
title_rating_df.set_index('tconst')
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21
# tt1069246             6.2       326
# tt1094666             7.0      1613
# tt1130982             6.4       571
# tt1156528             7.2       265
# tt1161457             4.2       148
# tt1171222             5.1      8296
# tt1174693             5.8      2381
# tt1181840             7.0      5494
# tt1193623             8.0         5
# tt1199588             5.5        74
# tt1204784             5.8         6
# tt1210166             7.6    326657
# tt1212419             6.5     87288
# tt1220911             5.0       941
# tt1229238             7.4    428142
# tt1232829             7.2    477771
# tt1235548             6.6      2725
# tt1243974             5.4     54646
# tt1250861             6.2       416
# tt1258812             4.0        21
# ...

# %%
title_basics_df.set_index('tconst')
# Out:
#                                                primary_title  \
# tconst
# tt0063540                                          Sunghursh
# tt0066787                    One Day Before the Rainy Season
# tt0069049                         The Other Side of the Wind
# tt0069204                                    Sabse Bada Sukh
# tt0100275                           The Wandering Soap Opera
# tt0111414                                        A Thin Life
# tt0112502                                            Bigfoot
# tt0137204                                    Joe Finds Grace
# tt0139613                                         O Silêncio
# tt0144449                              Nema aviona za Zagreb
# tt0146592                                        Pál Adrienn
# tt0154039                               So Much for Justice!
# tt0159369                 Cooper and Hemingway: The True Gen
# tt0162942                       Children of the Green Dragon
# ...

# %%
test_df = pd.merge(title_basics_df, title_rating_df, on = 'tconst', how = 'outer')

# %%
test_df
# Out:
#            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0069204                                    Sabse Bada Sukh
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# 6       tt0112502                                            Bigfoot
# 7       tt0137204                                    Joe Finds Grace
# 8       tt0139613                                         O Silêncio
# 9       tt0144449                              Nema aviona za Zagreb
# 10      tt0146592                                        Pál Adrienn
# 11      tt0154039                               So Much for Justice!
# 12      tt0159369                 Cooper and Hemingway: The True Gen
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# averagerating      73856 non-null float64
# numvotes           73856 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 10.0+ MB

# %%
test_df.sort_values('averagerating', ascending=False)
# Out:
#             tconst                                      primary_title  \
# 87675    tt5089804                    Fly High: Story of the Disc Dog
# 120584   tt7259300                                     Calamity Kevin
# 136750   tt8730716                      Pick It Up! - Ska in the '90s
# 144763   tt9715646                                           Renegade
# 120109   tt7227500  Ellis Island: The Making of a Master Race in A...
# 4016    tt10378660          The Dark Knight: The Ballad of the N Word
# 117359   tt6991826    A Dedicated Life: Phoebe Brand Beyond the Group
# 16767    tt1770682                               Freeing Bernie Baran
# 1857    tt10176328     Exteriores: Mulheres Brasileiras na Diplomacia
# 85426    tt4944240                          Dog Days in the Heartland
# 92455    tt5344358                                      All Around Us
# 71954    tt4109192                              I Was Born Yesterday!
# ...

# %%
test_df = test_df.fillna(0)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146144 non-null object
# start_year         146144 non-null int64
# runtime_minutes    146144 non-null float64
# genres             146144 non-null object
# averagerating      146144 non-null float64
# numvotes           146144 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 10.0+ MB

# %%
test_df['numvotes'] = pd.to_numeric(test_df['numvotes'])

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 8 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146144 non-null object
# start_year         146144 non-null int64
# runtime_minutes    146144 non-null float64
# genres             146144 non-null object
# averagerating      146144 non-null float64
# numvotes           146144 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 10.0+ MB

# %%
test_df
# Out:
#            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0069204                                    Sabse Bada Sukh
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# 6       tt0112502                                            Bigfoot
# 7       tt0137204                                    Joe Finds Grace
# 8       tt0139613                                         O Silêncio
# 9       tt0144449                              Nema aviona za Zagreb
# 10      tt0146592                                        Pál Adrienn
# 11      tt0154039                               So Much for Justice!
# 12      tt0159369                 Cooper and Hemingway: The True Gen
# ...

# %%
test_df = test_df[test_df['numvotes'] >= 100000]
movie_dict_df= test_df.drop(columns=['original_title', 'runtime_minutes'])

# %%
Movie_dict =movie_dict_df.set_index("tconst").T.to_dict("List")
Movie_dict
# Out:
# {'tt0359950': ['The Secret Life of Walter Mitty',
#   2013,
#   'Adventure,Comedy,Drama',
#   7.3,
#   275300.0],
#  'tt0365907': ['A Walk Among the Tombstones',
#   2014,
#   'Action,Crime,Drama',
#   6.5,
#   105116.0],
#  'tt0369610': ['Jurassic World',
#   2015,
#   'Action,Adventure,Sci-Fi',
#   7.0,
#   539338.0],
#  'tt0398286': ['Tangled', 2010, 'Adventure,Animation,Comedy', 7.8, 366366.0],
#  'tt0401729': ['John Carter', 2012, 'Action,Adventure,Sci-Fi', 6.6, 241792.0],
#  'tt0409847': ['Cowboys & Aliens',
#   2011,
#   'Action,Sci-Fi,Thriller',
#   6.0,
#   195889.0],
#  'tt0429493': ['The A-Team', 2010, 'Action,Adventure,Thriller', 6.8, 235256.0],
#  'tt0433035': ['Real Steel', 2011, 'Action,Drama,Family', 7.1, 283534.0],
#  'tt0435651': ['The Giver', 2014, 'Drama,Romance,Sci-Fi', 6.5, 104999.0],
#  'tt0435761': ['Toy Story 3',
#   2010,
#   'Adventure,Animation,Comedy',
#   8.3,
#   682218.0],
#  'tt0443272': ['Lincoln', 2012, 'Biography,Drama,History', 7.4, 228701.0],
# ...

# %%
def genre_lister():
    genre_list=[]
    for value in Movie_dict.values():
        genre_list.append(value[2])
    return genre_list

# %%
genre_lister()
# Out:
# ['Adventure,Comedy,Drama',
#  'Action,Crime,Drama',
#  'Action,Adventure,Sci-Fi',
#  'Adventure,Animation,Comedy',
#  'Action,Adventure,Sci-Fi',
#  'Action,Sci-Fi,Thriller',
#  'Action,Adventure,Thriller',
#  'Action,Drama,Family',
#  'Drama,Romance,Sci-Fi',
#  'Adventure,Animation,Comedy',
#  'Biography,Drama,History',
#  'Action,Comedy,Fantasy',
#  'Action,Adventure,Comedy',
#  'Action,Adventure,Animation',
#  'Action,Adventure,Fantasy',
#  'Adventure,Drama,Fantasy',
#  'Horror,Thriller',
#  'Action,Crime,Thriller',
#  'Action,Adventure,Sci-Fi',
#  'Crime,Thriller',
#  'Drama,Mystery,Sci-Fi',
#  'Action,Comedy,Crime',
#  'Action,Crime,Thriller',
#  'Action,Adventure,Fantasy',
#  'Comedy,Drama,Music',
#  'Action,Thriller',
#  'Drama,Fantasy',
#  'Action,Adventure,Comedy',
#  'Comedy,Romance',
#  'Action,Adventure,Animation',
#  'Comedy,Drama,Romance',
#  'Action,Adventure,Sci-Fi',
#  'Crime,Drama',
#  'Biography,Drama',
#  'Action,Crime,Thriller',
#  'Action,Adventure,Comedy',
# ...

# %%
genre_list
# Out:
# ['7']

# %%
def genre_hist():
    if genrel

# %%
test_df.sort_values('averagerating', ascending=False)
# Out:
#            tconst                              primary_title  \
# 99483   tt5813916                            The Mountain II
# 7066    tt1375666                                  Inception
# 72821   tt4154796                          Avengers: Endgame
# 311     tt0816692                               Interstellar
# 80655   tt4633694          Spider-Man: Into the Spider-Verse
# 87402   tt5074352                                     Dangal
# 72820   tt4154756                     Avengers: Infinity War
# 43376   tt2582802                                   Whiplash
# 13044   tt1675434                           The Intouchables
# 38424   tt2380307                                       Coco
# 20342   tt1853728                           Django Unchained
# 6900    tt1345836                      The Dark Knight Rises
# 91844   tt5311514                                 Your Name.
# 117014  tt6966692                                 Green Book
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 618 entries, 54 to 127205
# Data columns (total 8 columns):
# tconst             618 non-null object
# primary_title      618 non-null object
# original_title     618 non-null object
# start_year         618 non-null int64
# runtime_minutes    618 non-null float64
# genres             618 non-null object
# averagerating      618 non-null float64
# numvotes           618 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 43.5+ KB

# %%
films_from_list = []
for name in title_principals_df:
    print

# %%
title_principals_df
# Out:
#             tconst  ordering      nconst         category       job  \
# 0        tt0111414         1   nm0246005            actor       NaN
# 1        tt0111414         2   nm0398271         director       NaN
# 2        tt0111414         3   nm3739909         producer  producer
# 3        tt0323808        10   nm0059247           editor       NaN
# 4        tt0323808         1   nm3579312          actress       NaN
# 5        tt0323808         2   nm2694680            actor       NaN
# 6        tt0323808         3   nm0574615            actor       NaN
# 7        tt0323808         4   nm0502652          actress       NaN
# 8        tt0323808         5   nm0362736         director       NaN
# 9        tt0323808         6   nm0811056         producer  producer
# 10       tt0323808         7   nm0914939         producer  producer
# 11       tt0323808         8   nm0779346         composer       NaN
# 12       tt0323808         9   nm0676104  cinematographer       NaN
# ...

# %%
new_test_df = pd.merge(new_test_df, name_df, on = 'nconst', how = 'outer')

# %%
new_test_df
# Out:
#             tconst                       primary_title  \
# 0        tt0359950     The Secret Life of Walter Mitty
# 1        tt1790886                        The Campaign
# 2        tt2361509                          The Intern
# 3        tt3079380                                 Spy
# 4        tt1430626                                 NaN
# 5        tt1535438                                 NaN
# 6        tt2170593                                 NaN
# 7        tt2091256                                 NaN
# 8        tt1772288                                 NaN
# 9        tt2400463                                 NaN
# 10       tt4902012                                 NaN
# 11       tt7137380                                 NaN
# 12       tt5814534                                 NaN
# 13       tt7040874                                 NaN
# 14       tt8623904                                 NaN
# 15       tt0359950     The Secret Life of Walter Mitty
# ...
